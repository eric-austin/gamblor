# %% [raw]
# ---
# description: Trading and sports betting app
# output-file: index.html
# title: gamblor
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install gamblor
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# This lib provides a [`Card`](https://eric-austin.github.io/gamblor/card.html#card) class that you can use to create, display, and compare playing cards.

# %%
c1 = Card(suit=1, rank=3)
c2 = Card(suit=2, rank=10)
print(c1)
print(c2)
print(c1 < c2)
print(c1 > c2)
print(c1 == c2)
# Out:
# 3♦
# 10♥
# True
# False
# False
